# %% [markdown]
# # Confronti UE e OECD

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "demografia").exists():
    ROOT = ROOT.parent
panel = pd.read_parquet(ROOT / "output/data/final/oecd_demographic_indicators.parquet")
structure = pd.read_parquet(ROOT / "output/data/final/age_structure_indicators.parquet")

# %%
panel.query("indicator == 'fertilita_totale'").sort_values(["year", "iso3"]).tail(100)
